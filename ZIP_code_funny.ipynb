# %%
import geopandas as gpd

# %%
ZIP_codes = gpd.read_file('data/ZIP Codes/PSRC ZCTA/PSRC ZCTA.shp')
ZIP_codes['GEOID20'] = ZIP_codes['GEOID20'].astype(int)
ZIP_codes
# Out:
#     ZCTA5CE20  GEOID20 CLASSFP20 MTFCC20 FUNCSTAT20    ALAND20  AWATER20  \
# 0       98003    98003        B5   G6350          S   29787414    197598
# 1       98007    98007        B5   G6350          S   11188918     25498
# 2       98024    98024        B5   G6350          S   57194520   1228332
# 3       98042    98042        B5   G6350          S   71966524   1491751
# 4       98122    98122        B5   G6350          S    6050458   2020259
# ..        ...      ...       ...     ...        ...        ...       ...
# 184     98385    98385        B5   G6350          S    1911598     33843
# 185     98580    98580        B5   G6350          S  336917563   4540427
# 186     98370    98370        B5   G6350          S  145872950  25033417
# 187     98367    98367        B5   G6350          S  190441514   4522541
# 188     98371    98371        B5   G6350          S   30654928    284665
#
#       INTPTLAT20    INTPTLON20  \
# 0    +47.3052049  -122.3141614
# ...

# %%
index = ZIP_codes['GEOID20'].tolist()
ZIP_codes.index = index

ZIP_codes.to_file('PSRC ZCTA 3.shp')

# %%
ZIP_code_SEA = gpd.read_file('data/ZIP Codes/Seattle ZCTA/stl_2017_dest.shp')
ZIP_code_SEA
# Out:
#    ZCTA5CE         AFFGEOI GEOID10     ALAND10    AWATER1    pop  \
# 0    98174  8600000US98174   98174      9145.0        0.0   3552
# 1    98125  8600000US98125   98125  13958393.0  2727416.0  50486
# 2    98155  8600000US98155   98155  19566808.0  1765255.0  31603
# 3    98121  8600000US98121   98121   1149954.0   537254.0  25652
# 4    98146  8600000US98146   98146  12047172.0  1758214.0  41635
# 5    98154  8600000US98154   98154      9147.0        0.0   1252
# 6    98164  8600000US98164   98164      9165.0        0.0   4356
# 7    98195  8600000US98195   98195    180667.0    52419.0  22534
# 8    98117  8600000US98117   98117   9982059.0  1800762.0  43390
# 9    98104  8600000US98104   98104   2004182.0   252657.0  15598
# 10   98126  8600000US98126   98126   7930295.0  1808457.0  19662
# 11   98116  8600000US98116   98116   7660575.0  1877043.0  27724
# 12   98103  8600000US98103   98103  12005522.0  1705646.0  60556
# ...
